# %% [markdown]
# # Transformação e tratamento

# %% [markdown]
# ## Objetivo: Limpeza e tratamento
#
#
#
# - Seleção de colunas
#
# - Tratamento de nulos
#
# - Conversões de tipos
#
# - Outliers
#
# - Feature engineering
#
# - Salvamento em data/processed/

# %% [markdown]
# ## Introdução
#
# ### Transformação e Tratamento dos Dados (Transform)
#
# Este notebook corresponde à segunda etapa do processo ETL (Extract, Transform, Load) e tem como objetivo realizar o tratamento dos dados brutos extraídos do portal Inside Airbnb.
#
# Nesta fase, cada dataset é tratado separadamente, respeitando sua natureza e finalidade, garantindo qualidade, consistência e preparação adequada para a análise exploratória.

# %% [markdown]
# ## Objetivos da Etapa de Transformação
#
# Os principais objetivos desta etapa são:
#
# - Avaliar a qualidade dos dados brutos
# - Tratar valores ausentes e inconsistências
# - Padronizar tipos e categorias
# - Selecionar variáveis relevantes para análise
# - Criar datasets tratados e consistentes
# - Preservar rastreabilidade entre dados brutos e processados

# %% [markdown]
# ## Importação das Bibliotecas

# %%
# importação das bibliotecas

import pandas as pd 
import numpy as np 
import os
import geopandas as gpd

# %% [markdown]
# ## Carregamento dos Dados Brutos

# %%
base_path = "../data/raw/"

df_listings_raw = pd.read_csv(base_path + "listings.csv.gz")
df_neighbourhoods_raw = pd.read_csv(base_path + "neighbourhoods.csv")
df_neighbourhoods_geo_raw = gpd.read_file(base_path + "neighbourhoods.geojson")
df_listings = pd.read_csv(base_path + "listings.csv")

# %% [markdown]
# ## Tratamento do Dataset listings

# %%
# leitura dos dados brutos em detalhe
df_listings_raw.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0    958    https://www.airbnb.com/rooms/958  20251204025409   2025-12-04
# 1   5858   https://www.airbnb.com/rooms/5858  20251204025409   2025-12-04
# 2   8142   https://www.airbnb.com/rooms/8142  20251204025409   2025-12-04
# 3   8339   https://www.airbnb.com/rooms/8339  20251204025409   2025-12-04
# 4  10537  https://www.airbnb.com/rooms/10537  20251204025409   2025-12-04
#
#         source                                               name  \
# 0  city scrape              Bright, Modern Garden Unit - 1BR/1BTH
# 1  city scrape                                 Creative Sanctuary
# 2  city scrape  *FriendlyRoom Apt. Style -UCSF/USF - San Franc...
# 3  city scrape                    Historic Alamo Square Victorian
# 4  city scrape  Elegant & Cozy w/City views. Private room: Purple
#
#                                          description  \
# 0  Our bright garden unit overlooks a lovely back...
# 1  We live in a large Victorian house on a quiet ...
# 2  Nice and good public transportation.  7 minute...
# 3  For creative humans who love art, space, photo...
# 4  Casa de Paz (House of Peace) is like staying w...
#
#                                neighborhood_overview  \
# 0  Quiet cul de sac in friendly neighborhood<br /...
# 1  I love how our neighborhood feels quiet but is...
# 2  N Juda Muni, Bus and UCSF Shuttle.<br /><br />...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/be1bf5ac-a955...     1169  ...
# 1  https://a0.muscache.com/pictures/hosting/Hosti...     8904  ...
# 2  https://a0.muscache.com/pictures/hosting/Hosti...    21994  ...
# 3  https://a0.muscache.com/pictures/miso/Hosting-...    24215  ...
# 4  https://a0.muscache.com/pictures/airflow/Hosti...    36752  ...
#
#   review_scores_communication  review_scores_location review_scores_value  \
# 0                        4.90                    4.98                4.77
# 1                        4.85                    4.77                4.68
# 2                        4.80                    4.70                4.70
# 3                        5.00                    4.94                4.75
# 4                        5.00                    4.68                4.80
#
#           license instant_bookable  calculated_host_listings_count  \
# 0     STR-0006854                f                               1
# 1             NaN                f                               1
# 2             NaN                f                              20
# 3     STR-0000264                f                               1
# 4  2022-011003STR                f                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                            20
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                            0              2.54
# 1                                            0              0.52
# 2                                            0              0.07
# 3                                            0              0.13
# 4                                            0              0.24
#
# [5 rows x 85 columns]

# %%
df_listings_raw.shape
# Out:
# (7535, 85)

# %%
df_listings_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 85 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7535 non-null   int64
#  1   listing_url                                   7535 non-null   object
#  2   scrape_id                                     7535 non-null   int64
#  3   last_scraped                                  7535 non-null   object
#  4   source                                        7535 non-null   object
#  5   name                                          7535 non-null   object
#  6   description                                   7445 non-null   object
#  7   neighborhood_overview                         4168 non-null   object
#  8   picture_url                                   7535 non-null   object
#  9   host_id                                       7535 non-null   int64
#  10  host_url                                      7535 non-null   object
#  11  host_profile_id                               7535 non-null   int64
#  12  host_profile_url                              7535 non-null   object
#  13  host_name                                     7341 non-null   object
#  14  host_since                                    7341 non-null   object
#  15  hosts_time_as_user_years                      7341 non-null   float64
#  16  hosts_time_as_user_months                     7341 non-null   float64
#  17  hosts_time_as_host_years                      7161 non-null   float64
#  18  hosts_time_as_host_months                     7161 non-null   float64
#  19  host_location                                 5690 non-null   object
#  20  host_about                                    4491 non-null   object
#  21  host_response_time                            6237 non-null   object
#  22  host_response_rate                            6237 non-null   object
#  23  host_acceptance_rate                          6513 non-null   object
#  24  host_is_superhost                             7535 non-null   object
#  25  host_thumbnail_url                            7341 non-null   object
#  26  host_picture_url                              7341 non-null   object
#  27  host_neighbourhood                            7022 non-null   object
#  28  host_listings_count                           7341 non-null   float64
#  29  host_total_listings_count                     7341 non-null   float64
#  30  host_verifications                            7341 non-null   object
#  31  host_has_profile_pic                          7341 non-null   object
#  32  host_identity_verified                        7341 non-null   object
#  33  neighbourhood                                 4168 non-null   object
#  34  neighbourhood_cleansed                        7535 non-null   object
#  35  neighbourhood_group_cleansed                  0 non-null      float64
#  36  latitude                                      7535 non-null   float64
#  37  longitude                                     7535 non-null   float64
#  38  property_type                                 7535 non-null   object
#  39  room_type                                     7535 non-null   object
#  40  accommodates                                  7535 non-null   int64
#  41  bathrooms                                     5727 non-null   float64
#  42  bathrooms_text                                7476 non-null   object
#  43  bedrooms                                      7096 non-null   float64
#  44  beds                                          5692 non-null   float64
#  45  amenities                                     7535 non-null   object
#  46  price                                         0 non-null      float64
#  47  minimum_nights                                7535 non-null   int64
#  48  maximum_nights                                7535 non-null   int64
#  49  minimum_minimum_nights                        7523 non-null   float64
#  50  maximum_minimum_nights                        7523 non-null   float64
#  51  minimum_maximum_nights                        7523 non-null   float64
#  52  maximum_maximum_nights                        7523 non-null   float64
#  53  minimum_nights_avg_ntm                        7535 non-null   float64
#  54  maximum_nights_avg_ntm                        7535 non-null   float64
#  55  calendar_updated                              0 non-null      float64
#  56  has_availability                              7278 non-null   object
#  57  availability_30                               7535 non-null   int64
#  58  availability_60                               7535 non-null   int64
#  59  availability_90                               7535 non-null   int64
#  60  availability_365                              7535 non-null   int64
#  61  calendar_last_scraped                         7535 non-null   object
#  62  number_of_reviews                             7535 non-null   int64
#  63  number_of_reviews_ltm                         7535 non-null   int64
#  64  number_of_reviews_l30d                        7535 non-null   int64
#  65  availability_eoy                              7535 non-null   int64
#  66  number_of_reviews_ly                          7535 non-null   int64
#  67  estimated_occupancy_l365d                     7535 non-null   int64
#  68  estimated_revenue_l365d                       0 non-null      float64
#  69  first_review                                  5862 non-null   object
#  70  last_review                                   5862 non-null   object
#  71  review_scores_rating                          5862 non-null   float64
#  72  review_scores_accuracy                        5862 non-null   float64
#  73  review_scores_cleanliness                     5862 non-null   float64
#  74  review_scores_checkin                         5861 non-null   float64
#  75  review_scores_communication                   5862 non-null   float64
#  76  review_scores_location                        5861 non-null   float64
#  77  review_scores_value                           5861 non-null   float64
#  78  license                                       4898 non-null   object
#  79  instant_bookable                              7535 non-null   object
#  80  calculated_host_listings_count                7535 non-null   int64
#  81  calculated_host_listings_count_entire_homes   7535 non-null   int64
#  82  calculated_host_listings_count_private_rooms  7535 non-null   int64
#  83  calculated_host_listings_count_shared_rooms   7535 non-null   int64
#  84  reviews_per_month                             5862 non-null   float64
# dtypes: float64(29), int64(21), object(35)
# memory usage: 4.9+ MB

# %%
df_listings_raw.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_profile_id', 'host_profile_url', 'host_name',
#        'host_since', 'hosts_time_as_user_years', 'hosts_time_as_user_months',
#        'hosts_time_as_host_years', 'hosts_time_as_host_months',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
# informações iniciais dos dados resumidos 
df_listings.head()
# Out:
#       id                                               name  host_id  \
# 0    958              Bright, Modern Garden Unit - 1BR/1BTH     1169
# 1   5858                                 Creative Sanctuary     8904
# 2   8142  *FriendlyRoom Apt. Style -UCSF/USF - San Franc...    21994
# 3   8339                    Historic Alamo Square Victorian    24215
# 4  10537  Elegant & Cozy w/City views. Private room: Purple    36752
#
#        host_profile_id        host_name  neighbourhood_group  \
# 0  1462506189282101689            Holly                  NaN
# 1  1462506623299518225  Philip Jonathon                  NaN
# 2  1462506956810615042            Aaron                  NaN
# 3  1462506994551169471         Rosmarie                  NaN
# 4  1462507288958203289           Teresa                  NaN
#
#       neighbourhood  latitude  longitude        room_type  price  \
# 0  Western Addition  37.77028 -122.43317  Entire home/apt    NaN
# 1    Bernal Heights  37.74474 -122.42089  Entire home/apt    NaN
# 2    Haight Ashbury  37.76555 -122.45213     Private room    NaN
# 3  Western Addition  37.77377 -122.43614  Entire home/apt    NaN
# 4           Bayview  37.71750 -122.39698     Private room    NaN
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               2                507  2025-11-15               2.54
# 1              30                105  2017-08-06               0.52
# 2              32                 10  2023-07-30               0.07
# 3               9                 25  2019-06-28               0.13
# 4               1                 46  2025-11-07               0.24
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               1               228                     41
# 1                               1               365                      0
# 2                              20               362                      0
# 3                               1               339                      0
# 4                               3               365                     12
#
#           license
# 0     STR-0006854
# 1             NaN
# 2             NaN
# 3     STR-0000264
# 4  2022-011003STR

# %%
df_listings.shape
# Out:
# (7535, 19)

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7535 non-null   int64
#  1   name                            7535 non-null   object
#  2   host_id                         7535 non-null   int64
#  3   host_profile_id                 7535 non-null   int64
#  4   host_name                       7341 non-null   object
#  5   neighbourhood_group             0 non-null      float64
#  6   neighbourhood                   7535 non-null   object
#  7   latitude                        7535 non-null   float64
#  8   longitude                       7535 non-null   float64
#  9   room_type                       7535 non-null   object
#  10  price                           0 non-null      float64
#  11  minimum_nights                  7535 non-null   int64
#  12  number_of_reviews               7535 non-null   int64
#  13  last_review                     5862 non-null   object
#  14  reviews_per_month               5862 non-null   float64
#  15  calculated_host_listings_count  7535 non-null   int64
#  16  availability_365                7535 non-null   int64
#  17  number_of_reviews_ltm           7535 non-null   int64
#  18  license                         4898 non-null   object
# dtypes: float64(5), int64(8), object(6)
# memory usage: 1.1+ MB

# %%
df_listings.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_profile_id', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'number_of_reviews',
#        'last_review', 'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %% [markdown]
# ## Tratamento do Dataset listings

# %%
listings_cols = [
    'id',
    'name',
    'host_id',
    'host_name',
    'neighbourhood', 
    'latitude', 
    'longitude',
    'property_type', 
    'room_type', 
    'accommodates', 
    'bathrooms',
    'bathrooms_text', 
    'bedrooms', 
    'beds', 
    'minimum_nights', 
    'maximum_nights', 
    'has_availability',
    'availability_30', 
    'availability_60', 
    'availability_90',
    'availability_365', 
    'number_of_reviews',
    'first_review', 
    'last_review',
    'review_scores_rating', 
    'review_scores_accuracy',
    'review_scores_cleanliness',
    'review_scores_checkin', 
    'review_scores_location',
    'review_scores_value', 
    'license', 
    'instant_bookable',
    'calculated_host_listings_count',
    'reviews_per_month'
]

df = df_listings_raw[listings_cols].copy()

# %% [markdown]
# **As colunas `bathrooms` e `bathrooms_text` foram mantidas temporariamente
# durante a etapa de transformação para permitir a validação e imputação
# dos valores ausentes de banheiros. Após o tratamento, a coluna
# `bathrooms_text` foi removida por redundância.**

# %%
# verificando as colunas selecionadas
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'minimum_nights',
#        'maximum_nights', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_location', 'review_scores_value', 'license',
#        'instant_bookable', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
# verificando o tipo de dado
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7535 non-null   int64
#  1   name                            7535 non-null   object
#  2   host_id                         7535 non-null   int64
#  3   host_name                       7341 non-null   object
#  4   neighbourhood                   4168 non-null   object
#  5   latitude                        7535 non-null   float64
#  6   longitude                       7535 non-null   float64
#  7   property_type                   7535 non-null   object
#  8   room_type                       7535 non-null   object
#  9   accommodates                    7535 non-null   int64
#  10  bathrooms                       5727 non-null   float64
#  11  bathrooms_text                  7476 non-null   object
#  12  bedrooms                        7096 non-null   float64
#  13  beds                            5692 non-null   float64
#  14  minimum_nights                  7535 non-null   int64
#  15  maximum_nights                  7535 non-null   int64
#  16  has_availability                7278 non-null   object
#  17  availability_30                 7535 non-null   int64
#  18  availability_60                 7535 non-null   int64
#  19  availability_90                 7535 non-null   int64
#  20  availability_365                7535 non-null   int64
#  21  number_of_reviews               7535 non-null   int64
#  22  first_review                    5862 non-null   object
#  23  last_review                     5862 non-null   object
#  24  review_scores_rating            5862 non-null   float64
#  25  review_scores_accuracy          5862 non-null   float64
#  26  review_scores_cleanliness       5862 non-null   float64
#  27  review_scores_checkin           5861 non-null   float64
#  28  review_scores_location          5861 non-null   float64
#  29  review_scores_value             5861 non-null   float64
#  30  license                         4898 non-null   object
#  31  instant_bookable                7535 non-null   object
#  32  calculated_host_listings_count  7535 non-null   int64
#  33  reviews_per_month               5862 non-null   float64
# dtypes: float64(12), int64(11), object(11)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Significado de cada coluna

# %% [markdown]
# ### Dicionário de Dados — Dataset listings
#
# - **id** – identificador único do imóvel anunciado na plataforma Airbnb.
#
# - **name** – nome ou título do anúncio da propriedade.
#
# - **host_id** – identificador único do anfitrião (proprietário) do imóvel.
#
# - **host_name** – nome do anfitrião responsável pelo anúncio.
#
# - **neighbourhood** – nome do bairro onde o imóvel está localizado.
#
# - **latitude** – coordenada de latitude do imóvel, utilizada para análises geográficas.
#
# - **longitude** – coordenada de longitude do imóvel, utilizada para análises geográficas.
#
# - **property_type** – tipo da propriedade (ex.: apartamento, casa, quarto em residência, etc.).
#
# - **room_type** – tipo de acomodação ofertada (ex.: imóvel inteiro, quarto privado ou compartilhado).
#
# - **accommodates** – número máximo de pessoas que o imóvel pode acomodar.
#
# - **bathrooms** – número de banheiros disponíveis no imóvel.
#
# - **bathrooms_text** – descrição textual da quantidade e tipo de banheiros (ex.: “1 banheiro privativo”).
#
# - **bedrooms** – número de quartos disponíveis no imóvel.
#
# - **beds** – número total de camas disponíveis para os hóspedes.
#
# - **minimum_nights** – número mínimo de noites exigido para realizar uma reserva.
#
# - **maximum_nights** – número máximo de noites permitidas por reserva.
#
# - **has_availability** – indica se o imóvel possui disponibilidade para reservas no período analisado.
#
# - **availability_30** – número de dias disponíveis para reserva nos próximos 30 dias.
#
# - **availability_60** – número de dias disponíveis para reserva nos próximos 60 dias.
#
# - **availability_90** – número de dias disponíveis para reserva nos próximos 90 dias.
#
# - **availability_365** – número de dias disponíveis para reserva nos próximos 365 dias.
#
# - **number_of_reviews** – quantidade total de avaliações recebidas pelo imóvel.
#
# - **first_review** – data da primeira avaliação registrada para o imóvel.
#
# - **last_review** – data da avaliação mais recente registrada para o imóvel.
#
# - **review_scores_rating** – avaliação geral do imóvel atribuída pelos hóspedes.
#
# - **review_scores_accuracy** – avaliação referente à precisão das informações do anúncio.
#
# - **review_scores_cleanliness** – avaliação relacionada ao nível de limpeza do imóvel.
#
# - **review_scores_checkin** – avaliação da experiência de check-in realizada pelos hóspedes.
#
# - **review_scores_location** – avaliação da localização do imóvel.
#
# - **review_scores_value** – avaliação do custo-benefício percebido pelos hóspedes.
#
# - **license** – informação sobre a licença ou regularização do imóvel para locação, quando disponível.
#
# - **instant_bookable** – indica se o imóvel permite reserva imediata sem necessidade de aprovação do anfitrião.
#
# - **calculated_host_listings_count** – número total de anúncios ativos associados ao mesmo anfitrião.
#
# - **reviews_per_month** – média de avaliações recebidas pelo imóvel por mês.

# %%
df.head()
# Out:
#       id                                               name  host_id  \
# 0    958              Bright, Modern Garden Unit - 1BR/1BTH     1169
# 1   5858                                 Creative Sanctuary     8904
# 2   8142  *FriendlyRoom Apt. Style -UCSF/USF - San Franc...    21994
# 3   8339                    Historic Alamo Square Victorian    24215
# 4  10537  Elegant & Cozy w/City views. Private room: Purple    36752
#
#          host_name            neighbourhood  latitude  longitude  \
# 0            Holly  Neighborhood highlights  37.77028 -122.43317
# 1  Philip Jonathon  Neighborhood highlights  37.74474 -122.42089
# 2            Aaron  Neighborhood highlights  37.76555 -122.45213
# 3         Rosmarie                      NaN  37.77377 -122.43614
# 4           Teresa                      NaN  37.71750 -122.39698
#
#                  property_type        room_type  accommodates  ...  \
# 0    Entire serviced apartment  Entire home/apt             3  ...
# 1           Entire rental unit  Entire home/apt             4  ...
# 2  Private room in rental unit     Private room             1  ...
# 3                 Entire condo  Entire home/apt             2  ...
# 4                 Private room     Private room             2  ...
#
#    review_scores_rating review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.88                   4.94                       4.93
# 1                  4.87                   4.85                       4.87
# 2                  4.70                   4.50                       4.50
# 3                  4.86                   4.88                       5.00
# 4                  4.98                   4.93                       4.98
#
#    review_scores_checkin  review_scores_location  review_scores_value  \
# 0                   4.96                    4.98                 4.77
# 1                   4.89                    4.77                 4.68
# 2                   4.80                    4.70                 4.70
# 3                   4.94                    4.94                 4.75
# 4                   4.95                    4.68                 4.80
#
#           license  instant_bookable  calculated_host_listings_count  \
# 0     STR-0006854                 f                               1
# 1             NaN                 f                               1
# 2             NaN                 f                              20
# 3     STR-0000264                 f                               1
# 4  2022-011003STR                 f                               3
#
#    reviews_per_month
# 0               2.54
# 1               0.52
# 2               0.07
# 3               0.13
# 4               0.24
#
# [5 rows x 34 columns]

# %%
# verificar valores NaN (nulos / ausentes)
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                          194
# neighbourhood                     3367
# latitude                             0
# longitude                            0
# property_type                        0
# room_type                            0
# accommodates                         0
# bathrooms                         1808
# bathrooms_text                      59
# bedrooms                           439
# beds                              1843
# minimum_nights                       0
# maximum_nights                       0
# has_availability                   257
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews                    0
# first_review                      1673
# last_review                       1673
# review_scores_rating              1673
# review_scores_accuracy            1673
# review_scores_cleanliness         1673
# review_scores_checkin             1674
# review_scores_location            1674
# review_scores_value               1674
# license                           2637
# instant_bookable                     0
# calculated_host_listings_count       0
# reviews_per_month                 1673
# dtype: int64

# %%
# preencher com desconhecido os valores ausente de host_name e 'neighbourhood'
df['host_name'] = df['host_name'].fillna('Unknown')
df['neighbourhood'] = df['neighbourhood'].fillna('Unknown')

# %% [markdown]
# ### Tratamento de valores ausentes
#
# Os valores ausentes nas colunas `host_name` e `neighbourhood` foram preenchidos
# com a categoria `"Unknown"`. Essa decisão foi adotada para preservar os registros
# no dataset, evitando a exclusão de anúncios válidos.
#
# No caso de `host_name`, o identificador principal do anfitrião é a coluna
# `host_id`, o que garante a rastreabilidade mesmo quando o nome não está
# disponível. Para a variável `neighbourhood`, o valor `"Unknown"` indica
# explicitamente a ausência de informação geográfica fornecida pela fonte,
# permitindo sua inclusão em análises categóricas sem introduzir suposições.

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# property_type                        0
# room_type                            0
# accommodates                         0
# bathrooms                         1808
# bathrooms_text                      59
# bedrooms                           439
# beds                              1843
# minimum_nights                       0
# maximum_nights                       0
# has_availability                   257
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews                    0
# first_review                      1673
# last_review                       1673
# review_scores_rating              1673
# review_scores_accuracy            1673
# review_scores_cleanliness         1673
# review_scores_checkin             1674
# review_scores_location            1674
# review_scores_value               1674
# license                           2637
# instant_bookable                     0
# calculated_host_listings_count       0
# reviews_per_month                 1673
# dtype: int64

# %%
# verificar algumas colunas sobre a caracteritica do imóvel

cols = [
    'property_type', 
    'room_type', 
    'accommodates', 
    'bathrooms',
    'bathrooms_text', 
    'bedrooms', 
    'beds'
]

df_property = df[cols]

# %%
df_property.head(10)
# Out:
#                  property_type        room_type  accommodates  bathrooms  \
# 0    Entire serviced apartment  Entire home/apt             3        1.0
# 1           Entire rental unit  Entire home/apt             4        2.0
# 2  Private room in rental unit     Private room             1        4.0
# 3                 Entire condo  Entire home/apt             2        1.5
# 4                 Private room     Private room             2        1.5
# 5           Entire rental unit  Entire home/apt             2        1.0
# 6        Private room in condo     Private room             2        1.0
# 7  Private room in rental unit     Private room             1        3.0
# 8  Private room in rental unit     Private room             1        3.0
# 9  Private room in rental unit     Private room             2        1.5
#
#      bathrooms_text  bedrooms  beds
# 0            1 bath       1.0   2.0
# 1           2 baths       2.0   2.0
# 2    4 shared baths       3.0   1.0
# 3         1.5 baths       1.0   1.0
# 4  1.5 shared baths       1.0   1.0
# 5            1 bath       0.0   1.0
# 6     1 shared bath       1.0   1.0
# 7    3 shared baths       1.0   2.0
# 8    3 shared baths       1.0   2.0
# 9  1.5 shared baths       1.0   1.0

# %%
# verificando os valores ausentes de bathrooms_text
df_property.loc[df_property['bathrooms'].isna()]
# Out:
#                     property_type        room_type  accommodates  bathrooms  \
# 21    Private room in rental unit     Private room             1        NaN
# 26                   Entire condo  Entire home/apt             2        NaN
# 39    Private room in rental unit     Private room             1        NaN
# 40           Private room in home     Private room             2        NaN
# 47             Entire rental unit  Entire home/apt             2        NaN
# ...                           ...              ...           ...        ...
# 7387        Private room in condo     Private room             2        NaN
# 7402           Entire rental unit  Entire home/apt            10        NaN
# 7410                Room in hotel     Private room             4        NaN
# 7415                Room in hotel     Private room             2        NaN
# 7440           Entire rental unit  Entire home/apt             2        NaN
#
#         bathrooms_text  bedrooms  beds
# 21      1 private bath       NaN   NaN
# 26              1 bath       1.0   NaN
# 39       1 shared bath       NaN   NaN
# 40              1 bath       1.0   NaN
# 47              1 bath       1.0   NaN
# ...                ...       ...   ...
# 7387  1.5 shared baths       1.0   NaN
# 7402           2 baths       5.0   NaN
# 7410    1 private bath       NaN   NaN
# 7415    1 private bath       1.0   NaN
# 7440            1 bath       1.0   NaN
#
# [1808 rows x 7 columns]

# %%
# verificando os valores ausentes de bathrooms_text
df_property.loc[df_property['bathrooms_text'].isna()]
# Out:
#                     property_type        room_type  accommodates  bathrooms  \
# 176          Private room in home     Private room             2        NaN
# 177          Private room in home     Private room             2        NaN
# 231            Entire rental unit  Entire home/apt             2        NaN
# 3509         Private room in home     Private room             1        NaN
# 4216                Room in hotel       Hotel room            16        NaN
# 4217                Room in hotel       Hotel room            16        NaN
# 4218                Room in hotel       Hotel room            12        NaN
# 4219                Room in hotel       Hotel room            12        NaN
# 4220                Room in hotel       Hotel room            12        NaN
# 4221                Room in hotel       Hotel room             8        NaN
# 4229                Room in hotel       Hotel room             8        NaN
# 4272                Room in hotel       Hotel room            16        NaN
# 4629  Private room in rental unit     Private room             2        0.0
# 5623                Room in hotel       Hotel room             8        NaN
# 5624                Room in hotel       Hotel room             8        NaN
# 5625                Room in hotel       Hotel room            12        NaN
# 5626                Room in hotel       Hotel room            16        NaN
# 5627                Room in hotel       Hotel room            16        NaN
# 5630                Room in hotel       Hotel room             8        NaN
# 5631                Room in hotel       Hotel room             8        NaN
# 5632                Room in hotel       Hotel room            12        NaN
# 5633                Room in hotel       Hotel room            12        NaN
# 5634                Room in hotel       Hotel room            16        NaN
# 5635                Room in hotel       Hotel room            16        NaN
# 5651                Room in hotel       Hotel room             8        NaN
# 5652                Room in hotel       Hotel room            12        NaN
# 5653                Room in hotel       Hotel room            16        NaN
# 5969                Room in hotel       Hotel room             8        NaN
# 6339                Room in hotel       Hotel room             8        2.0
# 6340                Room in hotel       Hotel room            12        3.0
# 6582                Room in hotel     Private room             2        NaN
# 6654                Room in hotel       Hotel room            16        NaN
# 6655                Room in hotel       Hotel room             8        2.0
# 6741       Room in boutique hotel       Hotel room             4        NaN
# 6763       Room in boutique hotel       Hotel room             4        NaN
# 6765       Room in boutique hotel       Hotel room             4        NaN
# 6766       Room in boutique hotel       Hotel room             4        NaN
# 6768                Room in hotel       Hotel room             8        NaN
# 6795                Room in hotel       Hotel room             8        2.0
# 6796                Room in hotel       Hotel room             8        2.0
# 6804                Room in hotel       Hotel room             8        NaN
# 6805                Room in hotel       Hotel room             8        NaN
# 6826                Room in hotel       Hotel room             8        2.0
# 6827                Room in hotel       Hotel room             8        2.0
# 6828                Room in hotel       Hotel room             8        2.0
# 6843                Room in hotel       Hotel room             8        NaN
# 6999                Room in hotel       Hotel room             8        2.0
# 7000                Room in hotel       Hotel room             8        2.0
# 7001                Room in hotel       Hotel room             8        2.0
# 7002                Room in hotel       Hotel room             8        2.0
# 7041                Room in hotel     Private room             2        NaN
# 7133                Room in hotel       Hotel room             8        NaN
# 7134                Room in hotel       Hotel room             8        NaN
# 7135                Room in hotel       Hotel room             8        NaN
# 7225                Room in hotel       Hotel room            12        NaN
# 7226                Room in hotel       Hotel room             8        NaN
# 7227                Room in hotel       Hotel room            12        NaN
# 7234                Room in hotel       Hotel room             8        2.0
# 7282  Private room in rental unit     Private room             1        NaN
#
#      bathrooms_text  bedrooms  beds
# 176             NaN       1.0   1.0
# 177             NaN       1.0   1.0
# 231             NaN       1.0   1.0
# 3509            NaN       1.0   1.0
# 4216            NaN       4.0   NaN
# 4217            NaN       4.0   NaN
# 4218            NaN       3.0   NaN
# 4219            NaN       3.0   NaN
# 4220            NaN       3.0   NaN
# 4221            NaN       2.0   NaN
# 4229            NaN       2.0   NaN
# 4272            NaN       4.0   NaN
# 4629            NaN       1.0   1.0
# 5623            NaN       2.0   NaN
# 5624            NaN       2.0   NaN
# 5625            NaN       3.0   NaN
# 5626            NaN       4.0   NaN
# 5627            NaN       4.0   NaN
# 5630            NaN       2.0   NaN
# 5631            NaN       2.0   NaN
# 5632            NaN       3.0   NaN
# 5633            NaN       3.0   NaN
# 5634            NaN       4.0   NaN
# 5635            NaN       4.0   NaN
# 5651            NaN       2.0   NaN
# 5652            NaN       3.0   NaN
# 5653            NaN       4.0   NaN
# 5969            NaN       2.0   NaN
# 6339            NaN       2.0   0.0
# 6340            NaN       3.0   0.0
# 6582            NaN       1.0   NaN
# 6654            NaN       4.0   NaN
# 6655            NaN       2.0   0.0
# 6741            NaN       2.0   NaN
# 6763            NaN       2.0   NaN
# 6765            NaN       2.0   NaN
# 6766            NaN       2.0   NaN
# 6768            NaN       2.0   NaN
# 6795            NaN       2.0   4.0
# 6796            NaN       2.0   4.0
# 6804            NaN       2.0   NaN
# 6805            NaN       2.0   NaN
# 6826            NaN       2.0   0.0
# 6827            NaN       2.0   0.0
# 6828            NaN       2.0   0.0
# 6843            NaN       2.0   NaN
# 6999            NaN       2.0   0.0
# 7000            NaN       2.0   0.0
# 7001            NaN       2.0   0.0
# 7002            NaN       2.0   0.0
# 7041            NaN       1.0   NaN
# 7133            NaN       2.0   NaN
# 7134            NaN       2.0   NaN
# 7135            NaN       2.0   NaN
# 7225            NaN       3.0   NaN
# 7226            NaN       2.0   NaN
# 7227            NaN       3.0   NaN
# 7234            NaN       2.0   0.0
# 7282            NaN       1.0   1.0

# %%
# Extrarir da variavel bathrooms_text os valores  de bathrooms
df['bathrooms_from_text'] = (
    df['bathrooms_text']
    .str.extract(r'(\d+\.?\d*)')
    .astype(float)
)

df['bathrooms'] = df['bathrooms'].fillna(df['bathrooms_from_text'])

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# property_type                        0
# room_type                            0
# accommodates                         0
# bathrooms                           51
# bathrooms_text                      59
# bedrooms                           439
# beds                              1843
# minimum_nights                       0
# maximum_nights                       0
# has_availability                   257
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews                    0
# first_review                      1673
# last_review                       1673
# review_scores_rating              1673
# review_scores_accuracy            1673
# review_scores_cleanliness         1673
# review_scores_checkin             1674
# review_scores_location            1674
# review_scores_value               1674
# license                           2637
# instant_bookable                     0
# calculated_host_listings_count       0
# reviews_per_month                 1673
# bathrooms_from_text                 85
# dtype: int64

# %%
# inputar o valor de 1 se accommodates == 1
mask = df['bathrooms'].isna() & (df['accommodates'] == 1)
df.loc[mask, 'bathrooms'] = 1

# %%
# Regra 3: fallback por room_type
df['bathrooms'] = df.groupby('room_type')['bathrooms'].transform(
    lambda x: x.fillna(x.median())
)

# %%
# remover a coluna bathrooms_text
cols_to_drop = ['bathrooms_from_text', 'bathrooms_text']
df.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# #### Tratamento de valores ausentes — variável bathrooms
#
# A variável bathrooms apresentou uma quantidade relevante de valores ausentes. Para lidar com esse problema, foi adotada uma estratégia de imputação progressiva, priorizando informações mais específicas e reduzindo o risco de introdução de viés artificial nos dados.
#
# O tratamento foi realizado em três etapas sequenciais:
#
# 1️⃣ Extração a partir da variável bathrooms_text
#
# Inicialmente, os valores ausentes em bathrooms foram preenchidos a partir da variável textual bathrooms_text, que contém descrições como “1 bath”, “1.5 baths” ou “Shared bath”.
# Foi aplicada uma rotina de extração numérica para recuperar a quantidade de banheiros sempre que essa informação estivesse explicitamente disponível no texto.
#
# Essa etapa permitiu recuperar valores reais informados pelos anfitriões, preservando a fidelidade semântica dos dados originais.
#
# 2️⃣ Imputação baseada na capacidade de acomodação (accommodates)
#
# Na sequência, para os registros que ainda permaneceram com valores ausentes, foi aplicada a seguinte regra:
#
# Quando accommodates == 1, o valor de bathrooms foi imputado como 1.
#
# Essa decisão se baseia no padrão observado em anúncios do Airbnb, onde acomodações destinadas a uma única pessoa geralmente dispõem de ao menos um banheiro (privativo ou compartilhado).
# Essa regra representa uma imputação conservadora e plausível, evitando valores nulos em casos simples e frequentes.
#
# 3️⃣ Fallback por tipo de acomodação (room_type) usando a mediana
#
# Por fim, para os casos residuais em que ainda não havia informação disponível, foi adotada uma estratégia de fallback baseada no room_type.
# Nessa etapa, os valores ausentes de bathrooms foram preenchidos utilizando a mediana do número de banheiros dentro de cada categoria de tipo de quarto.
#
# A escolha da mediana — em vez da média — visa reduzir a influência de outliers e preservar a robustez estatística da imputação, respeitando diferenças estruturais entre tipos de acomodação, como Entire home/apt, Private room e Shared room.

# %%
cols = [
    'property_type', 
    'room_type', 
    'accommodates', 
    'bathrooms',
    'bedrooms', 
    'beds'
]

data_property = df[cols]

# %%
data_property.head(10)
# Out:
#                  property_type        room_type  accommodates  bathrooms  \
# 0    Entire serviced apartment  Entire home/apt             3        1.0
# 1           Entire rental unit  Entire home/apt             4        2.0
# 2  Private room in rental unit     Private room             1        4.0
# 3                 Entire condo  Entire home/apt             2        1.5
# 4                 Private room     Private room             2        1.5
# 5           Entire rental unit  Entire home/apt             2        1.0
# 6        Private room in condo     Private room             2        1.0
# 7  Private room in rental unit     Private room             1        3.0
# 8  Private room in rental unit     Private room             1        3.0
# 9  Private room in rental unit     Private room             2        1.5
#
#    bedrooms  beds
# 0       1.0   2.0
# 1       2.0   2.0
# 2       3.0   1.0
# 3       1.0   1.0
# 4       1.0   1.0
# 5       0.0   1.0
# 6       1.0   1.0
# 7       1.0   2.0
# 8       1.0   2.0
# 9       1.0   1.0

# %%
# verificando os valores ausentes de bathrooms_text
data_property.loc[data_property['bedrooms'].isna()]
# Out:
#                     property_type        room_type  accommodates  bathrooms  \
# 21    Private room in rental unit     Private room             1        1.0
# 39    Private room in rental unit     Private room             1        1.0
# 59           Private room in home     Private room             1        1.0
# 68    Private room in rental unit     Private room             1        1.5
# 92    Private room in rental unit     Private room             2        1.5
# ...                           ...              ...           ...        ...
# 7162         Private room in home     Private room             2        2.0
# 7250           Entire rental unit  Entire home/apt             4        1.0
# 7281         Private room in home     Private room             1        1.5
# 7294                Room in hotel     Private room             4        1.0
# 7410                Room in hotel     Private room             4        1.0
#
#       bedrooms  beds
# 21         NaN   NaN
# 39         NaN   NaN
# 59         NaN   NaN
# 68         NaN   NaN
# 92         NaN   NaN
# ...        ...   ...
# 7162       NaN   NaN
# 7250       NaN   NaN
# 7281       NaN   NaN
# 7294       NaN   NaN
# 7410       NaN   NaN
#
# [439 rows x 6 columns]

# %%
# inputar o valor 1 onde se tem 1 a accommodates tanto para bedrooms beds
mask = df['bedrooms'].isna() & (df['accommodates'] == 1)
df.loc[mask, 'bedrooms'] = 1

# %%
mask = df['beds'].isna() & (df['accommodates'] == 1)
df.loc[mask, 'beds'] = 1

# %%
cols = [
    'property_type', 
    'room_type', 
    'accommodates', 
    'bathrooms',
    'bedrooms', 
    'beds'
]

data_property = df[cols]

# %%
data_property.head(10)
# Out:
#                  property_type        room_type  accommodates  bathrooms  \
# 0    Entire serviced apartment  Entire home/apt             3        1.0
# 1           Entire rental unit  Entire home/apt             4        2.0
# 2  Private room in rental unit     Private room             1        4.0
# 3                 Entire condo  Entire home/apt             2        1.5
# 4                 Private room     Private room             2        1.5
# 5           Entire rental unit  Entire home/apt             2        1.0
# 6        Private room in condo     Private room             2        1.0
# 7  Private room in rental unit     Private room             1        3.0
# 8  Private room in rental unit     Private room             1        3.0
# 9  Private room in rental unit     Private room             2        1.5
#
#    bedrooms  beds
# 0       1.0   2.0
# 1       2.0   2.0
# 2       3.0   1.0
# 3       1.0   1.0
# 4       1.0   1.0
# 5       0.0   1.0
# 6       1.0   1.0
# 7       1.0   2.0
# 8       1.0   2.0
# 9       1.0   1.0

# %%
# verificando os valores ausentes de bathrooms_text
data_property.loc[data_property['bedrooms'].isna()]
# Out:
#                     property_type        room_type  accommodates  bathrooms  \
# 92    Private room in rental unit     Private room             2        1.5
# 115            Entire rental unit  Entire home/apt             2        1.0
# 181       Private room in cottage     Private room             2        1.0
# 249                  Entire condo  Entire home/apt             2        1.0
# 260   Private room in rental unit     Private room             2        1.0
# ...                           ...              ...           ...        ...
# 7161                Room in hotel     Private room             2        1.0
# 7162         Private room in home     Private room             2        2.0
# 7250           Entire rental unit  Entire home/apt             4        1.0
# 7294                Room in hotel     Private room             4        1.0
# 7410                Room in hotel     Private room             4        1.0
#
#       bedrooms  beds
# 92         NaN   NaN
# 115        NaN   1.0
# 181        NaN   NaN
# 249        NaN   NaN
# 260        NaN   NaN
# ...        ...   ...
# 7161       NaN   NaN
# 7162       NaN   NaN
# 7250       NaN   NaN
# 7294       NaN   NaN
# 7410       NaN   NaN
#
# [319 rows x 6 columns]

# %%
df['bedrooms'] = df.groupby('room_type')['bedrooms'].transform(
    lambda x: x.fillna(x.median())
)

# %%
df['beds'] = df.groupby('room_type')['beds'].transform(
    lambda x: x.fillna(x.median())
)

# %% [markdown]
# #### Tratamento de valores ausentes — variável bedrooms e beds
#
# A variável bathrooms apresentou uma quantidade relevante de valores ausentes. Para lidar com esse problema, foi adotada uma estratégia de imputação progressiva, priorizando informações mais específicas e reduzindo o risco de introdução de viés artificial nos dados.
#
# O tratamento foi realizado em duas etapas sequenciais:
#
# 1️⃣ Imputação baseada na capacidade de acomodação (accommodates)
#
# Na sequência, para os registros que ainda permaneceram com valores ausentes, foi aplicada a seguinte regra:
#
# Quando accommodates == 1, o valor de bedrooms e beds foi imputado como 1.
#
# Essa decisão se baseia no padrão observado em anúncios do Airbnb, onde acomodações destinadas a uma única pessoa geralmente dispõem de ao menos um quarto e uma cama (privativo ou compartilhado).
# Essa regra representa uma imputação conservadora e plausível, evitando valores nulos em casos simples e frequentes.
#
# 2️⃣ Fallback por tipo de acomodação (room_type) usando a mediana
#
# Por fim, para os casos residuais em que ainda não havia informação disponível, foi adotada uma estratégia de fallback baseada no room_type.
# Nessa etapa, os valores ausentes de bedrooms e beds foram preenchidos utilizando a mediana do número de banheiros dentro de cada categoria de tipo de quarto.
#
# A escolha da mediana — em vez da média — visa reduzir a influência de outliers e preservar a robustez estatística da imputação, respeitando diferenças estruturais entre tipos de acomodação, como Entire home/apt, Private room e Shared room.

# %%
cols = [
    'has_availability', 
    'availability_30', 
    'availability_60', 
    'availability_90',
    'availability_365'
]

data_availability = df[cols]

# %%
data_availability.head()
# Out:
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                4               10               15
# 1                t               30               60               90
# 2                t               27               57               87
# 3                t                4               34               64
# 4                t               30               60               90
#
#    availability_365
# 0               228
# 1               365
# 2               362
# 3               339
# 4               365

# %%
# tratamento da variavel has_availability (257 ausentes)
df['has_availability'] = df['has_availability'].fillna('f')

# %% [markdown]
# ### O que representa
#
# Indica se o anúncio possui disponibilidade ativa no calendário (t / f).
#
# ✅ Melhor tratamento
#
# Preencher com 'f' (False)
#
# 📌 Justificativa
#
# O dataset já possui as colunas availability_30, availability_60, availability_90 e availability_365
#
# Se todas essas colunas estão presentes, mas has_availability está ausente, o caso mais conservador é assumir não disponível
#
# Evita inflar artificialmente a oferta

# %%
## mantido reviews e datas nans e preenchido com 0 reviews_per_month
df['reviews_per_month'] = df['reviews_per_month'].fillna(0)

# %%
# preencher license com not provided
df['license'] = df['license'].fillna('Not provided')

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# property_type                        0
# room_type                            0
# accommodates                         0
# bathrooms                            0
# bedrooms                             0
# beds                                 0
# minimum_nights                       0
# maximum_nights                       0
# has_availability                     0
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews                    0
# first_review                      1673
# last_review                       1673
# review_scores_rating              1673
# review_scores_accuracy            1673
# review_scores_cleanliness         1673
# review_scores_checkin             1674
# review_scores_location            1674
# review_scores_value               1674
# license                              0
# instant_bookable                     0
# calculated_host_listings_count       0
# reviews_per_month                    0
# dtype: int64

# %% [markdown]
# **Os valores ausentes relacionados a reviews foram mantidos quando a ausência representava falta de avaliação real, evitando imputação artificial de notas. Para variáveis operacionais e categóricas, foram aplicadas imputações conservadoras, priorizando coerência semântica e redução de viés analítico.**

# %% [markdown]
# ## Salvar o dataset transformado

# %%
# Definir caminho
processed_path = "../data/processed/"

# Salvar em Parquet
df.to_parquet(processed_path + "listings_sanfrancisco_v1.parquet", index=False)

# Opcional: salvar CSV também
df.to_csv(processed_path + "listings_sanfrancisco_v1.csv", index=False)

# %% [markdown]
# ## Proximos passos
#
# - Use este dataset limpo e padronizado nas próximas etapas:
#
# - EDA (03_eda.ipynb)
#
# - Modelagem / análise estatística
#
# - Visualizações e dashboards
