# %% [markdown]
# # Transformação e tratamento

# %% [markdown]
# ## Objetivo: Limpeza e tratamento
#
#
#
# - Seleção de colunas
#
# - Tratamento de nulos
#
# - Conversões de tipos
#
# - Outliers
#
# - Feature engineering
#
# - Salvamento em data/processed/
