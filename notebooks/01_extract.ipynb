# %% [markdown]
# # Extração dos dados (Extract)
#
#
# Este notebook corresponde à primeira etapa do processo ETL (Extract, Transform, Load) e tem como objetivo realizar a extração e a inspeção inicial dos dados de locações do Airbnb para a cidade de San Francisco, Califórnia, EUA.
#
# Nesta fase, **nenhuma transformação é aplicada aos dados**. O foco está em compreender a estrutura do dataset bruto, verificar sua integridade e garantir rastreabilidade para as etapas posteriores do projeto.

# %% [markdown]
# ## Objetivo: Extração e inspeção inicial
#
# Conteúdo:
#
# - Fonte dos dados (Inside Airbnb)
#
# - Download / leitura do dataset
#
# - head(), info(), shape
#
# - Salvamento em data/raw/

# %% [markdown]
# - Obter os dados diretamente de uma fonte confiável (Inside Airbnb)
# - Garantir que os dados representem fielmente o fenômeno estudado
# - Preservar a integridade do dataset bruto
# - Realizar uma inspeção inicial da estrutura e dos tipos de dados
# - Preparar o ambiente para as etapas de transformação e análise
#
# Os dados utilizados neste projeto foram obtidos a partir do portal **Inside Airbnb**, uma iniciativa independente que disponibiliza dados públicos sobre locações de curta duração em diversas cidades do mundo, com o objetivo de promover transparência e apoiar análises acadêmicas e sociais.
#
# - Fonte: Inside Airbnb
# - Cidade: San Francisco, Califórnia, EUA
# - Dataset: listings.csv

# %% [markdown]
# ## Importação das Bibliotecas

# %%
# importação das Bibliotecas

import pandas as pd 
import geopandas as gpd

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Carregamento dos Datasets

# %%
# carregar múltiplos arquivos do inside airbnb

base_path = '../data/raw/'

df_listings_raw = pd.read_csv(base_path + "listings.csv.gz")
df_calendar_raw = pd.read_csv(base_path + "calendar.csv.gz")
df_reviews_raw = pd.read_csv(base_path + "reviews.csv.gz")
df_neighbourhoods_raw = pd.read_csv(base_path + "neighbourhoods.csv")
gdf_neighbourhoods_raw = gpd.read_file(base_path + "neighbourhoods.geojson")
df_listings = pd.read_csv(base_path + "listings.csv",low_memory=False)
df_reviews = pd.read_csv(base_path + "reviews.csv",low_memory=False)

# %% [markdown]
# ## Visualização inicial

# %%
# arquivo listings
df_listings_raw.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0    958    https://www.airbnb.com/rooms/958  20251204025409   2025-12-04
# 1   5858   https://www.airbnb.com/rooms/5858  20251204025409   2025-12-04
# 2   8142   https://www.airbnb.com/rooms/8142  20251204025409   2025-12-04
# 3   8339   https://www.airbnb.com/rooms/8339  20251204025409   2025-12-04
# 4  10537  https://www.airbnb.com/rooms/10537  20251204025409   2025-12-04
#
#         source                                               name  \
# 0  city scrape              Bright, Modern Garden Unit - 1BR/1BTH
# 1  city scrape                                 Creative Sanctuary
# 2  city scrape  *FriendlyRoom Apt. Style -UCSF/USF - San Franc...
# 3  city scrape                    Historic Alamo Square Victorian
# 4  city scrape  Elegant & Cozy w/City views. Private room: Purple
#
#                                          description  \
# 0  Our bright garden unit overlooks a lovely back...
# 1  We live in a large Victorian house on a quiet ...
# 2  Nice and good public transportation.  7 minute...
# 3  For creative humans who love art, space, photo...
# 4  Casa de Paz (House of Peace) is like staying w...
#
#                                neighborhood_overview  \
# 0  Quiet cul de sac in friendly neighborhood<br /...
# 1  I love how our neighborhood feels quiet but is...
# 2  N Juda Muni, Bus and UCSF Shuttle.<br /><br />...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/be1bf5ac-a955...     1169
# 1  https://a0.muscache.com/pictures/hosting/Hosti...     8904
# 2  https://a0.muscache.com/pictures/hosting/Hosti...    21994
# 3  https://a0.muscache.com/pictures/miso/Hosting-...    24215
# 4  https://a0.muscache.com/pictures/airflow/Hosti...    36752
#
#                                   host_url      host_profile_id  \
# 0   https://www.airbnb.com/users/show/1169  1462506189282101689
# 1   https://www.airbnb.com/users/show/8904  1462506623299518225
# 2  https://www.airbnb.com/users/show/21994  1462506956810615042
# 3  https://www.airbnb.com/users/show/24215  1462506994551169471
# 4  https://www.airbnb.com/users/show/36752  1462507288958203289
#
#                                     host_profile_url        host_name  \
# 0  https://www.airbnb.com/users/profile/146250618...            Holly
# 1  https://www.airbnb.com/users/profile/146250662...  Philip Jonathon
# 2  https://www.airbnb.com/users/profile/146250695...            Aaron
# 3  https://www.airbnb.com/users/profile/146250699...         Rosmarie
# 4  https://www.airbnb.com/users/profile/146250728...           Teresa
#
#    host_since  hosts_time_as_user_years  hosts_time_as_user_months  \
# 0  2008-07-31                      17.0                        4.0
# 1  2009-03-02                      16.0                        9.0
# 2  2009-06-17                      16.0                        5.0
# 3  2009-07-02                      16.0                        5.0
# 4  2009-09-07                      16.0                        2.0
#
#    hosts_time_as_host_years  hosts_time_as_host_months      host_location  \
# 0                      14.0                       11.0  San Francisco, CA
# 1                      14.0                       11.0  San Francisco, CA
# 2                      14.0                       11.0  San Francisco, CA
# 3                      14.0                       11.0  San Francisco, CA
# 4                      14.0                       11.0  San Francisco, CA
#
#                                           host_about  host_response_time  \
# 0  We are a family of four that live upstairs.  W...      within an hour
# 1  Philip: English transplant to the Bay Area and...  within a few hours
# 2  7 minutes walk to UCSF hospital & school campu...  within a few hours
# 3              I'm an Interior Stylist living in SF.  within a few hours
# 4                                 From San Francisco      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                92%                 100%                 t
# 1                80%                  79%                 f
# 2               100%                  86%                 t
# 3               100%                   0%                 f
# 4               100%                  96%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/efdad...
# 1  https://a0.muscache.com/im/users/8904/profile_...
# 2  https://a0.muscache.com/im/users/21994/profile...
# 3  https://a0.muscache.com/im/pictures/user/3e1a7...
# 4  https://a0.muscache.com/im/users/36752/profile...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/efdad...    Duboce Triangle
# 1  https://a0.muscache.com/im/users/8904/profile_...     Bernal Heights
# 2  https://a0.muscache.com/im/users/21994/profile...        Cole Valley
# 3  https://a0.muscache.com/im/pictures/user/3e1a7...       Alamo Square
# 4  https://a0.muscache.com/im/users/36752/profile...            Bayview
#
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  2.0                        2.0
# 2                 20.0                       21.0
# 3                  1.0                        5.0
# 4                  3.0                        4.0
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1  ['email', 'phone', 'work_email']                    t
# 2                ['email', 'phone']                    t
# 3                ['email', 'phone']                    t
# 4  ['email', 'phone', 'work_email']                    t
#
#   host_identity_verified            neighbourhood neighbourhood_cleansed  \
# 0                      t  Neighborhood highlights       Western Addition
# 1                      t  Neighborhood highlights         Bernal Heights
# 2                      t  Neighborhood highlights         Haight Ashbury
# 3                      t                      NaN       Western Addition
# 4                      t                      NaN                Bayview
#
#    neighbourhood_group_cleansed  latitude  longitude  \
# 0                           NaN  37.77028 -122.43317
# 1                           NaN  37.74474 -122.42089
# 2                           NaN  37.76555 -122.45213
# 3                           NaN  37.77377 -122.43614
# 4                           NaN  37.71750 -122.39698
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0    Entire serviced apartment  Entire home/apt             3        1.0
# 1           Entire rental unit  Entire home/apt             4        2.0
# 2  Private room in rental unit     Private room             1        4.0
# 3                 Entire condo  Entire home/apt             2        1.5
# 4                 Private room     Private room             2        1.5
#
#      bathrooms_text  bedrooms  beds  \
# 0            1 bath       1.0   2.0
# 1           2 baths       2.0   2.0
# 2    4 shared baths       3.0   1.0
# 3         1.5 baths       1.0   1.0
# 4  1.5 shared baths       1.0   1.0
#
#                                            amenities  price  minimum_nights  \
# 0  ["Private entrance", "Kitchenette", "Luggage d...    NaN               2
# 1  ["Private entrance", "Washer", "Hangers", "Iro...    NaN              30
# 2  ["Private entrance", "Dishes and silverware", ...    NaN              32
# 3  ["First aid kit", "Dishes and silverware", "Be...    NaN               9
# 4  ["Luggage dropoff allowed", "First aid kit", "...    NaN               1
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              30                     2.0                     2.0
# 1              90                    30.0                    30.0
# 2              90                    32.0                    32.0
# 3              91                     9.0                     9.0
# 4              90                     1.0                     1.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                  1125.0                  1125.0                     2.0
# 1                    90.0                    90.0                    30.0
# 2                    90.0                    90.0                    32.0
# 3                    91.0                    91.0                     9.0
# 4                    90.0                    90.0                     1.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                  1125.0               NaN                t                4
# 1                    90.0               NaN                t               30
# 2                    90.0               NaN                t               27
# 3                    91.0               NaN                t                4
# 4                    90.0               NaN                t               30
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               10               15               228            2025-12-04
# 1               60               90               365            2025-12-04
# 2               57               87               362            2025-12-04
# 3               34               64               339            2025-12-04
# 4               60               90               365            2025-12-04
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                507                     41                       1
# 1                105                      0                       0
# 2                 10                      0                       0
# 3                 25                      0                       0
# 4                 46                     12                       1
#
#    availability_eoy  number_of_reviews_ly  estimated_occupancy_l365d  \
# 0                 4                    50                        255
# 1                28                     0                          0
# 2                25                     0                          0
# 3                 2                     0                          0
# 4                28                    12                        132
#
#    estimated_revenue_l365d first_review last_review  review_scores_rating  \
# 0                      NaN   2009-07-23  2025-11-15                  4.88
# 1                      NaN   2009-05-03  2017-08-06                  4.87
# 2                      NaN   2014-09-08  2023-07-30                  4.70
# 3                      NaN   2010-04-14  2019-06-28                  4.86
# 4                      NaN   2010-02-21  2025-11-07                  4.98
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    4.94                       4.93                   4.96
# 1                    4.85                       4.87                   4.89
# 2                    4.50                       4.50                   4.80
# 3                    4.88                       5.00                   4.94
# 4                    4.93                       4.98                   4.95
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.90                    4.98                 4.77
# 1                         4.85                    4.77                 4.68
# 2                         4.80                    4.70                 4.70
# 3                         5.00                    4.94                 4.75
# 4                         5.00                    4.68                 4.80
#
#           license instant_bookable  calculated_host_listings_count  \
# 0     STR-0006854                f                               1
# 1             NaN                f                               1
# 2             NaN                f                              20
# 3     STR-0000264                f                               1
# 4  2022-011003STR                f                               3
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            0
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                            20
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               2.54
# 1                                            0               0.52
# 2                                            0               0.07
# 3                                            0               0.13
# 4                                            0               0.24

# %%
df_listings_raw.shape
# Out:
# (7535, 85)

# %%
# arquivo calendar
df_calendar_raw.head()
# Out:
#    listing_id        date available  price  adjusted_price  minimum_nights  \
# 0     1575184  2025-12-04         t    NaN             NaN               3
# 1     1575184  2025-12-05         t    NaN             NaN               3
# 2     1575184  2025-12-06         t    NaN             NaN               3
# 3     1575184  2025-12-07         t    NaN             NaN               3
# 4     1575184  2025-12-08         t    NaN             NaN               3
#
#    maximum_nights
# 0              28
# 1              28
# 2              28
# 3              28
# 4              28

# %%
df_calendar_raw.shape
# Out:
# (2750275, 7)

# %%
df_calendar_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2750275 entries, 0 to 2750274
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 146.9+ MB

# %%
df_calendar_raw.isna().sum()
# Out:
# listing_id              0
# date                    0
# available               0
# price             2750275
# adjusted_price    2750275
# minimum_nights          0
# maximum_nights          0
# dtype: int64

# %%
# reviews
df_reviews_raw.head()
# Out:
#    listing_id     id        date  reviewer_id reviewer_name  \
# 0         958   5977  2009-07-23        15695      Edmund C
# 1         958   6660  2009-08-03        26145         Simon
# 2         958  11519  2009-09-27        25839         Denis
# 3         958  16282  2009-11-05        33750          Anna
# 4         958  26008  2010-02-13        15416     V Jillian
#
#                                             comments
# 0  Our experience was, without a doubt, a five st...
# 1  Returning to San Francisco is a rejuvenating t...
# 2  We were very pleased with the accommodations a...
# 3  We highly recommend this accomodation and agre...
# 4  Holly's place was great. It was exactly what I...

# %%
df_reviews_raw.shape
# Out:
# (424402, 6)

# %%
# neighbourhoods - csv
df_neighbourhoods_raw.head()
# Out:
#    neighbourhood_group        neighbourhood
# 0                  NaN              Bayview
# 1                  NaN       Bernal Heights
# 2                  NaN  Castro/Upper Market
# 3                  NaN            Chinatown
# 4                  NaN       Crocker Amazon

# %%
df_neighbourhoods_raw.shape
# Out:
# (37, 2)

# %%
# gneighbourhoods geo_json
gdf_neighbourhoods_raw.head()
# Out:
#            neighbourhood neighbourhood_group  \
# 0               Seacliff                None
# 1         Haight Ashbury                None
# 2          Outer Mission                None
# 3  Downtown/Civic Center                None
# 4        Diamond Heights                None
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.48409 37.78791, -122.4843...
# 1  MULTIPOLYGON (((-122.43596 37.76904, -122.4368...
# 2  MULTIPOLYGON (((-122.45428 37.70822, -122.4545...
# 3  MULTIPOLYGON (((-122.40891 37.79013, -122.4088...
# 4  MULTIPOLYGON (((-122.43553 37.74146, -122.4356...

# %%
gdf_neighbourhoods_raw.shape
# Out:
# (37, 3)

# %%
# listings.csv
df_listings.head()
# Out:
#       id                                               name  host_id  \
# 0    958              Bright, Modern Garden Unit - 1BR/1BTH     1169
# 1   5858                                 Creative Sanctuary     8904
# 2   8142  *FriendlyRoom Apt. Style -UCSF/USF - San Franc...    21994
# 3   8339                    Historic Alamo Square Victorian    24215
# 4  10537  Elegant & Cozy w/City views. Private room: Purple    36752
#
#        host_profile_id        host_name  neighbourhood_group  \
# 0  1462506189282101689            Holly                  NaN
# 1  1462506623299518225  Philip Jonathon                  NaN
# 2  1462506956810615042            Aaron                  NaN
# 3  1462506994551169471         Rosmarie                  NaN
# 4  1462507288958203289           Teresa                  NaN
#
#       neighbourhood  latitude  longitude        room_type  price  \
# 0  Western Addition  37.77028 -122.43317  Entire home/apt    NaN
# 1    Bernal Heights  37.74474 -122.42089  Entire home/apt    NaN
# 2    Haight Ashbury  37.76555 -122.45213     Private room    NaN
# 3  Western Addition  37.77377 -122.43614  Entire home/apt    NaN
# 4           Bayview  37.71750 -122.39698     Private room    NaN
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               2                507  2025-11-15               2.54
# 1              30                105  2017-08-06               0.52
# 2              32                 10  2023-07-30               0.07
# 3               9                 25  2019-06-28               0.13
# 4               1                 46  2025-11-07               0.24
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               1               228                     41
# 1                               1               365                      0
# 2                              20               362                      0
# 3                               1               339                      0
# 4                               3               365                     12
#
#           license
# 0     STR-0006854
# 1             NaN
# 2             NaN
# 3     STR-0000264
# 4  2022-011003STR

# %%
df_listings.shape
# Out:
# (7535, 19)

# %%
df_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7535 entries, 0 to 7534
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7535 non-null   int64
#  1   name                            7535 non-null   object
#  2   host_id                         7535 non-null   int64
#  3   host_profile_id                 7535 non-null   int64
#  4   host_name                       7341 non-null   object
#  5   neighbourhood_group             0 non-null      float64
#  6   neighbourhood                   7535 non-null   object
#  7   latitude                        7535 non-null   float64
#  8   longitude                       7535 non-null   float64
#  9   room_type                       7535 non-null   object
#  10  price                           0 non-null      float64
#  11  minimum_nights                  7535 non-null   int64
#  12  number_of_reviews               7535 non-null   int64
#  13  last_review                     5862 non-null   object
#  14  reviews_per_month               5862 non-null   float64
#  15  calculated_host_listings_count  7535 non-null   int64
#  16  availability_365                7535 non-null   int64
#  17  number_of_reviews_ltm           7535 non-null   int64
#  18  license                         4898 non-null   object
# dtypes: float64(5), int64(8), object(6)
# memory usage: 1.1+ MB

# %%
df_reviews.head()
# Out:
#    listing_id        date
# 0         958  2009-07-23
# 1         958  2009-08-03
# 2         958  2009-09-27
# 3         958  2009-11-05
# 4         958  2010-02-13

# %%
# organização por tipo de dado
raw_data = {
    "listings": df_listings_raw,
    "calendar": df_calendar_raw,
    "reviews": df_reviews_raw,
    "neighbourhoods": df_neighbourhoods_raw,
    "neighbourhoods_geo": gdf_neighbourhoods_raw
}

# %% [markdown]
# ## Documentação
#
# ### Conjuntos de dados carregados
#
# - **df_listings_raw**: informações detalhada dos anúncios
# - **df_calendar_raw**: disponibilidade e preços por data
# - **df_reviews_raw**: avaliações detalhada e comentários dos hóspedes
# - **df_neighbourhoods_raw**: dados geográficos dos bairros
# - **df_listings**: informações resumida dos anúncios
# - **df_reviews**: avaliações e comentários dos hóspedes resumida

# %% [markdown]
# ### Limitação dos dados:
#
#
#
# Os datasets disponibilizados pelo Inside Airbnb para a cidade de San Francisco
# não incluem informações sobre o preço das acomodações (`price`). Essa limitação
# da fonte de dados restringe a análise a aspectos estruturais, geográficos e de
# avaliação dos anúncios, excluindo investigações relacionadas à precificação ou
# dimensão financeira.
