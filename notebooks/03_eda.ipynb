# %% [markdown]
# # Análise Exploratória

# %% [markdown]
# ## Objetivo: Análise Exploratória
#
# - Estatísticas descritivas
#
# - Visualizações
#
# - Insights
#
# - Storytelling
#
# 📌 Sem alterar os dados.
